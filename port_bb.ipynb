# %%
import pandas as pd
import numpy as np
data = pd.read_csv('./data/data_.csv', index_col=0)
df = data.dropna()
df
# Out:
#             KOSPI Index  M1WO Index  M1EF Index  KBPMABIN Index  \
# Date
# 2011-01-03      2070.08     3144.21      441.67        182.0300
# 2011-01-04      2085.14     3147.51      442.26        181.9900
# 2011-01-05      2082.55     3137.59      440.72        181.9400
# 2011-01-06      2077.61     3134.38      438.45        181.6600
# 2011-01-07      2086.20     3128.90      435.47        181.6600
# ...                 ...         ...         ...             ...
# 2021-11-19      2971.02     9708.98      624.90        255.2599
# 2021-11-22      3013.25     9654.31      621.17        255.0528
# 2021-11-23      2997.33     9640.55      618.14        254.7994
# 2021-11-24      2994.29     9644.51      617.05        254.9307
# 2021-11-26      2936.44     9445.56      602.30        256.4988
#
#             BTSYTRUH Index  JPEIGLBL Index  LGCPTRUU Index  RUGL Index  \
# Date
# 2011-01-03        480.3136          525.12        196.2308    2936.090
# 2011-01-04        479.9600          528.55        196.1033    2920.480
# 2011-01-05        478.3874          526.63        194.0989    2922.980
# 2011-01-06        477.8845          525.87        194.0285    2908.840
# 2011-01-07        478.6380          525.46        194.4800    2903.130
# ...                    ...             ...             ...         ...
# 2021-11-19        703.0671          919.80        298.4202    6629.446
# 2021-11-22        701.1487          916.35        296.5574    6589.466
# 2021-11-23        699.0779          909.54        295.1875    6601.330
# 2021-11-24        699.2002          908.83        295.2689    6662.500
# 2021-11-26        704.3186          905.23        297.6269    6512.336
#
#             BCOMTR Index  BCOMGCTR Index
# Date
# 2011-01-03      326.3951        366.9905
# 2011-01-04      321.5105        355.6178
# 2011-01-05      322.9517        354.3039
# 2011-01-06      319.2964        353.7896
# 2011-01-07      317.1871        353.0689
# ...                  ...             ...
# 2021-11-19      218.4979        435.9218
# 2021-11-22      218.0332        425.2975
# 2021-11-23      220.4872        419.9381
# 2021-11-24      221.2268        420.0798
# 2021-11-26      213.7845        420.3630
#
# [2578 rows x 10 columns]

# %%
returns = df.pct_change()
returns = returns.dropna()
returns
# Out:
#             KOSPI Index  M1WO Index  M1EF Index  KBPMABIN Index  \
# Date
# 2011-01-04     0.007275    0.001050    0.001336       -0.000220
# 2011-01-05    -0.001242   -0.003152   -0.003482       -0.000275
# 2011-01-06    -0.002372   -0.001023   -0.005151       -0.001539
# 2011-01-07     0.004135   -0.001748   -0.006797        0.000000
# 2011-01-10    -0.002584   -0.004503   -0.009484        0.000385
# ...                 ...         ...         ...             ...
# 2021-11-19     0.008021   -0.001991   -0.003635       -0.001980
# 2021-11-22     0.014214   -0.005631   -0.005969       -0.000811
# 2021-11-23    -0.005283   -0.001425   -0.004878       -0.000994
# 2021-11-24    -0.001014    0.000411   -0.001763        0.000515
# 2021-11-26    -0.019320   -0.020628   -0.023904        0.006151
#
#             BTSYTRUH Index  JPEIGLBL Index  LGCPTRUU Index  RUGL Index  \
# Date
# 2011-01-04       -0.000736        0.006532       -0.000650   -0.005317
# 2011-01-05       -0.003277       -0.003633       -0.010221    0.000856
# 2011-01-06       -0.001051       -0.001443       -0.000363   -0.004838
# 2011-01-07        0.001577       -0.000780        0.002327   -0.001963
# 2011-01-10        0.000218       -0.001085       -0.001157   -0.004846
# ...                    ...             ...             ...         ...
# 2021-11-19        0.002305        0.002059        0.001990   -0.004335
# 2021-11-22       -0.002729       -0.003751       -0.006242   -0.006031
# 2021-11-23       -0.002953       -0.007432       -0.004619    0.001800
# 2021-11-24        0.000175       -0.000781        0.000276    0.009266
# 2021-11-26        0.007320       -0.003961        0.007986   -0.022539
#
#             BCOMTR Index  BCOMGCTR Index
# Date
# 2011-01-04     -0.014965       -0.030989
# 2011-01-05      0.004483       -0.003695
# 2011-01-06     -0.011318       -0.001452
# 2011-01-07     -0.006606       -0.002037
# 2011-01-10      0.005388        0.003810
# ...                  ...             ...
# 2021-11-19     -0.002320       -0.005203
# 2021-11-22     -0.002127       -0.024372
# 2021-11-23      0.011255       -0.012602
# 2021-11-24      0.003354        0.000337
# 2021-11-26     -0.033641        0.000674
#
# [2577 rows x 10 columns]

# %% [markdown]
# $$ t t+1 사이의 수익율 R_{t,t+1} = \frac{P_{t+1}-P_{t}}{P_{t}} $$

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
returns.std() # sample standard deviation
# Out:
# KOSPI Index       0.010690
# M1WO Index        0.009686
# M1EF Index        0.010605
# KBPMABIN Index    0.001652
# BTSYTRUH Index    0.001655
# JPEIGLBL Index    0.003744
# LGCPTRUU Index    0.002946
# RUGL Index        0.010188
# BCOMTR Index      0.008794
# BCOMGCTR Index    0.010502
# dtype: float64

# %%
deviations = returns - returns.mean()
squared_deviation = deviations ** 2
number_of_observations = squared_deviation.count()
variance = squared_deviation.sum() / (number_of_observations - 1)
volatility = np.sqrt(variance)
volatility
# Out:
# KOSPI Index       0.010690
# M1WO Index        0.009686
# M1EF Index        0.010605
# KBPMABIN Index    0.001652
# BTSYTRUH Index    0.001655
# JPEIGLBL Index    0.003744
# LGCPTRUU Index    0.002946
# RUGL Index        0.010188
# BCOMTR Index      0.008794
# BCOMGCTR Index    0.010502
# dtype: float64

# %%
returns.std()*np.sqrt(252) # annualized volatility
# Out:
# KOSPI Index       0.169698
# M1WO Index        0.153763
# M1EF Index        0.168352
# KBPMABIN Index    0.026221
# BTSYTRUH Index    0.026274
# JPEIGLBL Index    0.059437
# LGCPTRUU Index    0.046764
# RUGL Index        0.161733
# BCOMTR Index      0.139607
# BCOMGCTR Index    0.166715
# dtype: float64

# %%
returns.mean()
# Out:
# KOSPI Index       0.000193
# M1WO Index        0.000474
# M1EF Index        0.000177
# KBPMABIN Index    0.000134
# BTSYTRUH Index    0.000150
# JPEIGLBL Index    0.000218
# LGCPTRUU Index    0.000166
# RUGL Index        0.000362
# BCOMTR Index     -0.000125
# BCOMGCTR Index    0.000108
# dtype: float64

# %%
np.prod(returns+1)-1
# Out:
# KOSPI Index       0.418515
# M1WO Index        2.004112
# M1EF Index        0.363688
# KBPMABIN Index    0.409102
# BTSYTRUH Index    0.466372
# JPEIGLBL Index    0.723854
# LGCPTRUU Index    0.516719
# RUGL Index        1.218030
# BCOMTR Index     -0.345013
# BCOMGCTR Index    0.145433
# dtype: float64

# %%
(((returns+1).prod()-1)*100).round(2)
# Out:
# KOSPI Index        41.85
# M1WO Index        200.41
# M1EF Index         36.37
# KBPMABIN Index     40.91
# BTSYTRUH Index     46.64
# JPEIGLBL Index     72.39
# LGCPTRUU Index     51.67
# RUGL Index        121.80
# BCOMTR Index      -34.50
# BCOMGCTR Index     14.54
# dtype: float64

# %%
from pandas_datareader import data as web
import yfinance as yf
yf.pdr_override()

# %%
# tickers = ['ACWI', 'VEA', 'EEM', 'AIA', 'AGG', 'EMB', 'TIP']
# tickers = ['VTI', 'TLT', 'IEF', 'DBC', 'GLD']
tickers = ['AAPL', 'F', 'AMZN', 'GE', 'TSLA']
adjClose = pd.DataFrame()

# %%
for ticker in tickers:
    adjClose[ticker] = web.get_data_yahoo(ticker, start='2007-01-01')['Adj Close']
adjClose.info()

# FinanceDataReader의 경우 과거의 데이터가 잘 조회되지 않는 문제가 있었음
# for ticker in tickers:
#     adjClose[ticker] = fdr.DataReader(ticker, start='2010-01-01')['Close']
# adjClose.info()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3745 entries, 2007-01-03 to 2021-11-15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3745 non-null   float64
#  1   F       3745 non-null   float64
#  2   AMZN    3745 non-null   float64
#  3   GE      3745 non-null   float64
#  4   TSLA    2867 non-null   float64
# dtypes: float64(5)
# memory usage: 175.5 KB

# %%
dailySimpleReturns = adjClose.pct_change()
dailySimpleReturns
# Out:
#                 AAPL         F      AMZN        GE      TSLA
# Date
# 2007-01-03       NaN       NaN       NaN       NaN       NaN
# 2007-01-04  0.022196  0.025300  0.005168 -0.005794       NaN
# 2007-01-05 -0.007122 -0.010389 -0.013625 -0.005033       NaN
# 2007-01-08  0.004938  0.014436 -0.022674 -0.000266       NaN
# 2007-01-09  0.083070  0.007762  0.007467  0.000000       NaN
# ...              ...       ...       ...       ...       ...
# 2021-11-09  0.002459 -0.001489  0.025007  0.026471 -0.119903
# 2021-11-10 -0.019163 -0.037773 -0.026335 -0.020936  0.043429
# 2021-11-11 -0.000338  0.009814 -0.002743 -0.017988 -0.004157
# 2021-11-12  0.014337 -0.002558  0.015162  0.005514 -0.028293
# 2021-11-15  0.000067  0.018462  0.005824 -0.008551 -0.019382
#
# [3745 rows x 5 columns]

# %%
meanReturns = dailySimpleReturns.mean()
annualReturns = meanReturns * 250
annualReturns
# Out:
# AAPL    0.323125
# F       0.183487
# AMZN    0.371887
# GE      0.023508
# TSLA    0.623153
# dtype: float64

# %%
numAssets = len(tickers) # 종목 수
weights = np.random.random(numAssets)
weights /= np.sum(weights)
portReturnsExpected = np.sum(weights * meanReturns.T)
# 포트폴리오 가중평균 기대수익율
portReturnsExpected
# Out:
# 0.0010840236862934942

# %%
# 행렬연산을 위하여 weights를 matirx 데이터형으로 변환
weights = np.matrix(weights)

# dailySimpleReturns는 pandas의 DataFrame개체이다
print('dailySimpleReturns의 데이터형: ',type(dailySimpleReturns))

# DataFrame 개체는 공분산을 계산해주는 cov함수를 제공한다.
# cov 함수는 DataFrame을 돌려준다
print('dailySimpleReturns.cov() 결과의 데이터형: ',type(dailySimpleReturns.cov()))

# 행렬연산을 위하여 cov()함수로 공분산한 결과를 
# 바로 values함수를 사용하여 행렬로 변환한다
pcov=dailySimpleReturns.cov().values

# 행렬연산으로 분산을 계산한다
varp = weights*pcov*weights.T 
print('포트폴리오 분산은 ', varp)
# Out:
# dailySimpleReturns의 데이터형:  <class 'pandas.core.frame.DataFrame'>
# dailySimpleReturns.cov() 결과의 데이터형:  <class 'pandas.core.frame.DataFrame'>
# 포트폴리오 분산은  [[0.00028707]]

# %%
dailyCov = dailySimpleReturns.cov()
annualCov = dailyCov * 250

# %%
portfolioReturns = []
portfolioVolatility = []
portfolioWeights = []

numPortfolios = 30000

for n in range(numPortfolios):
    weights = np.random.random(numAssets)
    weights /= np.sum(weights)
    returns = np.dot(weights, annualReturns)
    volatility = np.sqrt(np.dot(weights.T, np.dot(annualCov, weights)))
    portfolioReturns.append(returns)
    portfolioVolatility.append(volatility)
    portfolioWeights.append(weights)

# %%
portfolioVolatility = np.array(portfolioVolatility)
portfolioReturns = np.array(portfolioReturns)
colors = portfolioReturns / portfolioVolatility
plt.style.use('seaborn')
plt.scatter(portfolioVolatility, portfolioReturns, c=colors, marker='o', cmap=mpl.cm.jet)
plt.xlabel('Volatility')
plt.ylabel('Returns')
plt.title('Efficient Frontier')
plt.show()
